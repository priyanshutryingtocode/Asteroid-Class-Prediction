# %%
import pandas as pd

asteroid = pd.read_csv(r'C:\Users\priya\OneDrive\Desktop\PR Project\Dataset\dataset.csv')

asteroid.info()
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_25972\3067619736.py:3: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   asteroid = pd.read_csv(r'C:\Users\priya\OneDrive\Desktop\PR Project\Dataset\dataset.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              958524 non-null  object
#  1   spkid           958524 non-null  int64
#  2   full_name       958524 non-null  object
#  3   pdes            958524 non-null  object
#  4   name            22064 non-null   object
#  5   prefix          18 non-null      object
#  6   neo             958520 non-null  object
#  7   pha             938603 non-null  object
#  8   H               952261 non-null  float64
#  9   diameter        136209 non-null  float64
#  10  albedo          135103 non-null  float64
# ...

# %%
asteroid2=asteroid.drop(['id','spkid','full_name','name','prefix','orbit_id','epoch','epoch_mjd','epoch_cal','equinox','tp_cal'],axis=1)
asteroid2
# Out:
#             pdes neo pha       H  diameter  albedo  diameter_sigma         e  \
# 0              1   N   N   3.400   939.400  0.0900           0.200  0.076009
# 1              2   N   N   4.200   545.000  0.1010          18.000  0.229972
# 2              3   N   N   5.330   246.596  0.2140          10.594  0.256936
# 3              4   N   N   3.000   525.400  0.4228           0.200  0.088721
# 4              5   N   N   6.900   106.699  0.2740           3.140  0.190913
# ...          ...  ..  ..     ...       ...     ...             ...       ...
# 958519  6013 P-L   N   N  17.135       NaN     NaN             NaN  0.185919
# 958520  6331 P-L   N   N  18.500       NaN     NaN             NaN  0.282920
# 958521  6344 P-L   Y   Y  20.400       NaN     NaN             NaN  0.662446
# 958522  2060 T-2   N   N  18.071       NaN     NaN             NaN  0.202053
# 958523  2678 T-3   N   N  18.060       NaN     NaN             NaN  0.258348
#
# ...

# %%
asteroid3=asteroid2.drop(['sigma_a','sigma_e','sigma_q','sigma_i','sigma_om','sigma_w','sigma_ma','sigma_ad','sigma_n','sigma_tp','sigma_per','pdes'],axis=1)
asteroid3
# Out:
#        neo pha       H  diameter  albedo  diameter_sigma         e         a  \
# 0        N   N   3.400   939.400  0.0900           0.200  0.076009  2.769165
# 1        N   N   4.200   545.000  0.1010          18.000  0.229972  2.773841
# 2        N   N   5.330   246.596  0.2140          10.594  0.256936  2.668285
# 3        N   N   3.000   525.400  0.4228           0.200  0.088721  2.361418
# 4        N   N   6.900   106.699  0.2740           3.140  0.190913  2.574037
# ...     ..  ..     ...       ...     ...             ...       ...       ...
# 958519   N   N  17.135       NaN     NaN             NaN  0.185919  2.280861
# 958520   N   N  18.500       NaN     NaN             NaN  0.282920  2.334910
# 958521   Y   Y  20.400       NaN     NaN             NaN  0.662446  2.817152
# 958522   N   N  18.071       NaN     NaN             NaN  0.202053  2.373137
# 958523   N   N  18.060       NaN     NaN             NaN  0.258348  2.260404
#
# ...

# %%
asteroid3['pha'].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %%
asteroid3['neo'] = asteroid3['neo'].replace({'Y': 1, 'N': 0})
asteroid3['pha'] = asteroid3['pha'].replace({'Y': 1, 'N': 0})
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_25972\1294802033.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   asteroid3['neo'] = asteroid3['neo'].replace({'Y': 1, 'N': 0})
# C:\Users\priya\AppData\Local\Temp\ipykernel_25972\1294802033.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   asteroid3['pha'] = asteroid3['pha'].replace({'Y': 1, 'N': 0})

# %%
asteroid3
# Out:
#         neo  pha       H  diameter  albedo  diameter_sigma         e  \
# 0       0.0  0.0   3.400   939.400  0.0900           0.200  0.076009
# 1       0.0  0.0   4.200   545.000  0.1010          18.000  0.229972
# 2       0.0  0.0   5.330   246.596  0.2140          10.594  0.256936
# 3       0.0  0.0   3.000   525.400  0.4228           0.200  0.088721
# 4       0.0  0.0   6.900   106.699  0.2740           3.140  0.190913
# ...     ...  ...     ...       ...     ...             ...       ...
# 958519  0.0  0.0  17.135       NaN     NaN             NaN  0.185919
# 958520  0.0  0.0  18.500       NaN     NaN             NaN  0.282920
# 958521  1.0  1.0  20.400       NaN     NaN             NaN  0.662446
# 958522  0.0  0.0  18.071       NaN     NaN             NaN  0.202053
# 958523  0.0  0.0  18.060       NaN     NaN             NaN  0.258348
#
#                a         q          i  ...          ma        ad         n  \
# ...

# %%
asteroid3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   neo             958520 non-null  float64
#  1   pha             938603 non-null  float64
#  2   H               952261 non-null  float64
#  3   diameter        136209 non-null  float64
#  4   albedo          135103 non-null  float64
#  5   diameter_sigma  136081 non-null  float64
#  6   e               958524 non-null  float64
#  7   a               958524 non-null  float64
#  8   q               958524 non-null  float64
#  9   i               958524 non-null  float64
#  10  om              958524 non-null  float64
#  11  w               958524 non-null  float64
#  12  ma              958523 non-null  float64
#  13  ad              958520 non-null  float64
#  14  n               958524 non-null  float64
#  15  tp              958524 non-null  float64
# ...

# %%
asteroid4 = asteroid3.drop(columns=['diameter', 'albedo', 'diameter_sigma'])

asteroid4
# Out:
#         neo  pha       H         e         a         q          i          om  \
# 0       0.0  0.0   3.400  0.076009  2.769165  2.558684  10.594067   80.305531
# 1       0.0  0.0   4.200  0.229972  2.773841  2.135935  34.832932  173.024741
# 2       0.0  0.0   5.330  0.256936  2.668285  1.982706  12.991043  169.851482
# 3       0.0  0.0   3.000  0.088721  2.361418  2.151909   7.141771  103.810804
# 4       0.0  0.0   6.900  0.190913  2.574037  2.082619   5.367427  141.571026
# ...     ...  ...     ...       ...       ...       ...        ...         ...
# 958519  0.0  0.0  17.135  0.185919  2.280861  1.856807   5.984416  194.229902
# 958520  0.0  0.0  18.500  0.282920  2.334910  1.674319   8.082280  355.248239
# 958521  1.0  1.0  20.400  0.662446  2.817152  0.950941   4.679278  182.982832
# 958522  0.0  0.0  18.071  0.202053  2.373137  1.893638   0.732484  176.499082
# 958523  0.0  0.0  18.060  0.258348  2.260404  1.676433   9.661947  204.512448
#
# ...

# %%
asteroid4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 19 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   neo      958520 non-null  float64
#  1   pha      938603 non-null  float64
#  2   H        952261 non-null  float64
#  3   e        958524 non-null  float64
#  4   a        958524 non-null  float64
#  5   q        958524 non-null  float64
#  6   i        958524 non-null  float64
#  7   om       958524 non-null  float64
#  8   w        958524 non-null  float64
#  9   ma       958523 non-null  float64
#  10  ad       958520 non-null  float64
#  11  n        958524 non-null  float64
#  12  tp       958524 non-null  float64
#  13  per      958520 non-null  float64
#  14  per_y    958523 non-null  float64
#  15  moid     938603 non-null  float64
#  16  moid_ld  958397 non-null  float64
#  17  class    958524 non-null  object
#  18  rms      958522 non-null  float64
# ...

# %%
asteroid4.isna().sum()
# Out:
# neo            4
# pha        19921
# H           6263
# e              0
# a              0
# q              0
# i              0
# om             0
# w              0
# ma             1
# ad             4
# n              0
# tp             0
# per            4
# per_y          1
# moid       19921
# moid_ld      127
# class          0
# rms            2
# dtype: int64

# %%
asteroid4.dropna(inplace=True)
asteroid4
# Out:
#         neo  pha       H         e         a         q          i          om  \
# 0       0.0  0.0   3.400  0.076009  2.769165  2.558684  10.594067   80.305531
# 1       0.0  0.0   4.200  0.229972  2.773841  2.135935  34.832932  173.024741
# 2       0.0  0.0   5.330  0.256936  2.668285  1.982706  12.991043  169.851482
# 3       0.0  0.0   3.000  0.088721  2.361418  2.151909   7.141771  103.810804
# 4       0.0  0.0   6.900  0.190913  2.574037  2.082619   5.367427  141.571026
# ...     ...  ...     ...       ...       ...       ...        ...         ...
# 958519  0.0  0.0  17.135  0.185919  2.280861  1.856807   5.984416  194.229902
# 958520  0.0  0.0  18.500  0.282920  2.334910  1.674319   8.082280  355.248239
# 958521  1.0  1.0  20.400  0.662446  2.817152  0.950941   4.679278  182.982832
# 958522  0.0  0.0  18.071  0.202053  2.373137  1.893638   0.732484  176.499082
# 958523  0.0  0.0  18.060  0.258348  2.260404  1.676433   9.661947  204.512448
#
# ...

# %%
asteroid4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 932335 entries, 0 to 958523
# Data columns (total 19 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   neo      932335 non-null  float64
#  1   pha      932335 non-null  float64
#  2   H        932335 non-null  float64
#  3   e        932335 non-null  float64
#  4   a        932335 non-null  float64
#  5   q        932335 non-null  float64
#  6   i        932335 non-null  float64
#  7   om       932335 non-null  float64
#  8   w        932335 non-null  float64
#  9   ma       932335 non-null  float64
#  10  ad       932335 non-null  float64
#  11  n        932335 non-null  float64
#  12  tp       932335 non-null  float64
#  13  per      932335 non-null  float64
#  14  per_y    932335 non-null  float64
#  15  moid     932335 non-null  float64
#  16  moid_ld  932335 non-null  float64
#  17  class    932335 non-null  object
#  18  rms      932335 non-null  float64
# ...

# %%
asteroid4['pha'] = asteroid4['pha'].astype('int32')
asteroid4['neo'] = asteroid4['neo'].astype('int32')

asteroid4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 932335 entries, 0 to 958523
# Data columns (total 19 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   neo      932335 non-null  int32
#  1   pha      932335 non-null  int32
#  2   H        932335 non-null  float64
#  3   e        932335 non-null  float64
#  4   a        932335 non-null  float64
#  5   q        932335 non-null  float64
#  6   i        932335 non-null  float64
#  7   om       932335 non-null  float64
#  8   w        932335 non-null  float64
#  9   ma       932335 non-null  float64
#  10  ad       932335 non-null  float64
#  11  n        932335 non-null  float64
#  12  tp       932335 non-null  float64
#  13  per      932335 non-null  float64
#  14  per_y    932335 non-null  float64
#  15  moid     932335 non-null  float64
#  16  moid_ld  932335 non-null  float64
#  17  class    932335 non-null  object
#  18  rms      932335 non-null  float64
# ...

# %%
asteroid4.isna().sum()
# Out:
# neo        0
# pha        0
# H          0
# e          0
# a          0
# q          0
# i          0
# om         0
# w          0
# ma         0
# ad         0
# n          0
# tp         0
# per        0
# per_y      0
# moid       0
# moid_ld    0
# class      0
# rms        0
# dtype: int64

# %%
asteroid3['neo'].fillna(asteroid4['neo'].mode()[0], inplace=True)
asteroid3['pha'].fillna(0, inplace=True)
asteroid3['H'].fillna(asteroid4['H'].median(), inplace=True)
asteroid3.dropna(subset=['ma', 'ad'], inplace=True)

asteroid3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 958519 entries, 0 to 958523
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   neo             958519 non-null  float64
#  1   pha             958519 non-null  float64
#  2   H               958519 non-null  float64
#  3   diameter        136209 non-null  float64
#  4   albedo          135103 non-null  float64
#  5   diameter_sigma  136081 non-null  float64
#  6   e               958519 non-null  float64
#  7   a               958519 non-null  float64
#  8   q               958519 non-null  float64
#  9   i               958519 non-null  float64
#  10  om              958519 non-null  float64
#  11  w               958519 non-null  float64
#  12  ma              958519 non-null  float64
#  13  ad              958519 non-null  float64
#  14  n               958519 non-null  float64
#  15  tp              958519 non-null  float64
# ...

# %%
asteroid3['moid'].fillna(asteroid4['moid'].median(), inplace=True)
asteroid3['rms'].fillna(asteroid4['rms'].mean(), inplace=True)


asteroid3.drop(columns=['moid_ld'], inplace=True)

asteroid3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 958519 entries, 0 to 958523
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   neo             958519 non-null  float64
#  1   pha             958519 non-null  float64
#  2   H               958519 non-null  float64
#  3   diameter        136209 non-null  float64
#  4   albedo          135103 non-null  float64
#  5   diameter_sigma  136081 non-null  float64
#  6   e               958519 non-null  float64
#  7   a               958519 non-null  float64
#  8   q               958519 non-null  float64
#  9   i               958519 non-null  float64
#  10  om              958519 non-null  float64
#  11  w               958519 non-null  float64
#  12  ma              958519 non-null  float64
#  13  ad              958519 non-null  float64
#  14  n               958519 non-null  float64
#  15  tp              958519 non-null  float64
# ...

# %%
print(asteroid3.columns)

asteroid3.info()
# Out:
# Index(['neo', 'pha', 'H', 'e', 'a', 'q', 'i', 'om', 'w', 'ma', 'ad', 'n', 'tp',
#        'per', 'per_y', 'moid', 'class', 'rms'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 958519 entries, 0 to 958523
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   neo     958519 non-null  float64
#  1   pha     958519 non-null  float64
#  2   H       958519 non-null  float64
#  3   e       958519 non-null  float64
#  4   a       958519 non-null  float64
#  5   q       958519 non-null  float64
#  6   i       958519 non-null  float64
#  7   om      958519 non-null  float64
#  8   w       958519 non-null  float64
#  9   ma      958519 non-null  float64
#  10  ad      958519 non-null  float64
#  11  n       958519 non-null  float64
#  12  tp      958519 non-null  float64
#  13  per     958519 non-null  float64
#  14  per_y   958519 non-null  float64
#  15  moid    958519 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')

# %%
asteroid3['pha'] = asteroid3['pha'].astype('int32')
asteroid3['neo'] = asteroid3['neo'].astype('int32')

asteroid3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 958519 entries, 0 to 958523
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   neo     958519 non-null  int32
#  1   pha     958519 non-null  int32
#  2   H       958519 non-null  float64
#  3   e       958519 non-null  float64
#  4   a       958519 non-null  float64
#  5   q       958519 non-null  float64
#  6   i       958519 non-null  float64
#  7   om      958519 non-null  float64
#  8   w       958519 non-null  float64
#  9   ma      958519 non-null  float64
#  10  ad      958519 non-null  float64
#  11  n       958519 non-null  float64
#  12  tp      958519 non-null  float64
#  13  per     958519 non-null  float64
#  14  per_y   958519 non-null  float64
#  15  moid    958519 non-null  float64
#  16  class   958519 non-null  object
#  17  rms     958519 non-null  float64
# dtypes: float64(15), int32(2), object(1)
# memory usage: 131.6+ MB
